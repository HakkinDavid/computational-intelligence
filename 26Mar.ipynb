# %% [markdown]
# # ASL Recognition with CNNs
#
# This notebook implements a Convolutional Neural Network (CNN) for recognizing American Sign Language (ASL) gestures. We will compare the performance of a Fully Connected Neural Network (FCNN) with that of a CNN on the ASL dataset.
#
# For more information on the ASL alphabet, you can refer to this site: https://www.asl.gs/

# %%
import random

import torch.nn as nn
import pandas as pd
import torch
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.is_available()
# Out:
# True

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

data_base_path = "./data/" if IN_COLAB else "./datasets/asl_data/"

# %% [markdown]
# ### Load data
#
# The data for the ASL dataset is stored in CSV files. It is already split into training, validation, and test sets. Each row in the CSV files contains pixel values for a 28x28 image (flattened into a single row) and a label indicating the ASL gesture.
#
# The labels are integers from 0 to 23, corresponding to the letters A-Z (J and Z are excluded because they require movement).
#
# The images are grayscale, so each pixel value ranges from 0 to 255.

# %%
train_df = pd.read_csv(data_base_path + "train.csv")
val_df = pd.read_csv(data_base_path + "val.csv")
test_df = pd.read_csv(data_base_path + "test.csv")

# %%
def label_to_letter(lbl):
    letter_code = ord('A') + int(lbl)
    return chr(letter_code) if letter_code < ord('J') else chr(letter_code + 1)

def show(img, lbl):
    i = img.reshape(28,28)
    plt.figure(figsize=(5,5))
    plt.title(label_to_letter(lbl), fontdict={'fontsize': 30})
    plt.axis('off')
    plt.imshow(i, cmap='gray')

# %%
rnd_idx = random.choice(train_df.index)
image = train_df.iloc[rnd_idx].drop('label').values
label = train_df.iloc[rnd_idx]['label']
show(image, label)

# %% [markdown]
# ## Preparing dataset
#
# Let's start by creating the custom Dataset class for our ASL data. This class will take a DataFrame as input and will return the image and label for each sample. We will also normalize the pixel values to be between 0 and 1. The images will be reshaped as a 28x28 tensor with a single channel (grayscale).

# %%
IMG_HEIGHT = 28
IMG_WIDTH = 28
IMG_CHANNELS = 1

class AslDataset(Dataset):
    def __init__(self, base_df):
        x_df = base_df.copy()
        y_df = x_df.pop('label')
        x_df = x_df.values / 255
        x_df = x_df.reshape(-1, IMG_CHANNELS, IMG_WIDTH, IMG_HEIGHT)
        self.xs = torch.tensor(x_df).float().to(device)
        self.ys = torch.tensor(y_df).long().to(device)

    def __getitem__(self, idx):
        x = self.xs[idx]
        y = self.ys[idx]
        return x, y

    def __len__(self):
        return len(self.xs)

# %%
train_data = AslDataset(train_df)
val_data = AslDataset(val_df)
test_data = AslDataset(test_df)

# %%
batch_size = 32

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Training functions
#
# Now we can define our training functions. Since we will use accuracy to evaluate our model, we will create a function to calculate accuracy as well.

# %%
def get_batch_accuracy(output, y, N):
    pred = output.argmax(dim=1, keepdim=True)
    correct = pred.eq(y.view_as(pred)).sum().item()
    return correct / N

# %% [markdown]
# Our train function performs the full training loop. For each epoch, it computes the training loss and accuracy, and then evaluates the model on the validation set. It returns the history of training and validation losses and accuracies for plotting later.

# %%
def train(_model, _train_loader, _val_loader, _criterion, _optimizer, _num_epochs):
    res = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': [],
    }
    iterator = tqdm(range(epochs), desc="Training", unit="epoch")

    for _ in iterator:
        _model.train()
        train_loss = 0.0
        train_acc = 0.0
        for X_batch, y_batch in _train_loader:
            _optimizer.zero_grad()
            outputs = _model(X_batch)
            loss = _criterion(outputs, y_batch)
            loss.backward()
            _optimizer.step()
            train_loss += loss.item() * X_batch.size(0)
            train_acc += get_batch_accuracy(outputs, y_batch, len(_train_loader.dataset))

        epoch_train_loss = train_loss / len(_train_loader.dataset)

        _model.eval()
        val_loss = 0.0
        val_acc = 0.0
        with torch.no_grad():
            for X_val, y_val in _val_loader:
                val_outputs = _model(X_val)
                val_loss += _criterion(val_outputs, y_val).item() * X_val.size(0)
                val_acc += get_batch_accuracy(val_outputs, y_val, len(_val_loader.dataset))

        epoch_val_loss = val_loss / len(_val_loader.dataset)

        iterator.set_postfix(
            train_loss=f"{epoch_train_loss:.4f}",
            train_acc=f"{train_acc:.4f}",
            val_loss=f"{epoch_val_loss:.4f}",
            val_acc=f"{val_acc:.4f}",
        )

        res['train_loss'].append(epoch_train_loss)
        res['train_acc'].append(train_acc)
        res['val_loss'].append(epoch_val_loss)
        res['val_acc'].append(val_acc)

    return res

# %% [markdown]
# This test function will evaluate the model on the test set after training is complete. It will calculate the average loss and accuracy across the entire test set.

# %%
def test(_model, _test_loader, _loss_function):
    _model.eval()
    test_loss = 0.0
    test_acc = 0.0
    with torch.no_grad():
        for x, y in _test_loader:
            output = _model(x)
            test_loss += _loss_function(output, y).item() * x.size(0)
            test_acc += get_batch_accuracy(output, y, len(_test_loader.dataset))

    return (test_loss / len(_test_loader.dataset)), test_acc

# %% [markdown]
# ## Training the models

# %% [markdown]
# ### Baseline model - fully connected network
#
# Before we implement the CNN, let's train a simple fully connected neural network (FCNN) as a baseline. This will help us understand the performance improvement that the CNN architecture provides for image data.

# %%
model_fcnn = nn.Sequential(
    nn.Flatten(),
    nn.Linear(IMG_HEIGHT * IMG_WIDTH, 512),
    nn.ReLU(),
    nn.Dropout(.3),

    nn.Linear(512, 512),
    nn.ReLU(),
    nn.Linear(512, 24)
)

model_fcnn = model_fcnn.to(device)

# %%
epochs = 20
loss_function = nn.CrossEntropyLoss()
optimizer = Adam(model_fcnn.parameters())

fcnn_res = train(model_fcnn, train_loader, val_loader, loss_function, optimizer, epochs)
# Out:
# Training: 100%|██████████| 20/20 [00:26<00:00,  1.32s/epoch, train_acc=0.8923, train_loss=0.3055, val_acc=0.7797, val_loss=0.8478]

# %%
fcnn_test_loss, fcnn_test_acc = test(model_fcnn, test_loader, loss_function)

# %% [markdown]
# ### CNN model
#
# Now let's implement a simple CNN architecture. We will use three convolutional layers followed by max pooling, and then a couple of fully connected layers before the output layer.

# %%
model_cnn = nn.Sequential(
    nn.Conv2d(IMG_CHANNELS, 25, 3, stride=1, padding=1),  # 25 x 28 x 28
    nn.ReLU(),
    nn.MaxPool2d(2, stride=2),  # 25 x 14 x 14

    nn.Conv2d(25, 50, 3, stride=1, padding=1),  # 50 x 14 x 14
    nn.ReLU(),
    nn.Dropout(.2),
    nn.MaxPool2d(2, stride=2),  # 50 x 7 x 7

    nn.Conv2d(50, 75, 3, stride=1, padding=1),  # 75 x 7 x 7
    nn.ReLU(),
    nn.MaxPool2d(2, stride=2),  # 75 x 3 x 3

    nn.Flatten(),
    nn.Linear(75 * 3 * 3, 512),
    nn.Dropout(.3),
    nn.ReLU(),
    nn.Linear(512, 24)
)

model_cnn = model_cnn.to(device)

# %%
epochs = 20
loss_function = nn.CrossEntropyLoss()
optimizer = Adam(model_cnn.parameters())

cnn_res = train(model_cnn, train_loader, val_loader, loss_function, optimizer, epochs)
# Out:
# Training: 100%|██████████| 20/20 [00:35<00:00,  1.77s/epoch, train_acc=0.9980, train_loss=0.0072, val_acc=0.9554, val_loss=0.2264]

# %%
cnn_test_loss, cnn_test_acc = test(model_cnn, test_loader, loss_function)

# %% [markdown]
# ## Reflection section

# %% [markdown]
# ### Which model is better at classifying ASL images?

# %%
comparison_dict = {
    'Modelo': ['FCNN', 'CNN'],
    'Pérdida de prueba': [fcnn_test_loss, cnn_test_loss],
    'Exactitud de prueba': [fcnn_test_acc, cnn_test_acc]
}

pd.DataFrame(comparison_dict)
# Out:
#   Modelo  Pérdida de prueba  Exactitud de prueba
# 0   FCNN           0.840221             0.774958
# 1    CNN           0.235012             0.957613

# %% [markdown]
# Si no estoy viendo mal, la red neuronal convolusional es absolutamente mejor. La FCNN tiene pérdida prácticamente total (83.2%) y la CNN tiene mucho menos (19.95%), la exactitud de la FCNN es 71.66% y la de CNN es 96.73%.

# %% [markdown]
# ### Which model was _faster_ to train?

# %% [markdown]
# La FCNN, ya que tardó solo 23 segundos. La CNN tardó 32 segundos.

# %% [markdown]
# ### Plot and compare the learning curves of both models. What do you observe about their training and validation performance over epochs?

# %%
epochs_range = range(epochs)
plt.plot(epochs_range, fcnn_res.get('train_loss'), label="FCNN")
plt.plot(epochs_range, cnn_res.get('train_loss'), label="CNN")
plt.legend()
plt.title("Pérdida de entrenamiento")
plt.show()

epochs_range = range(epochs)
plt.plot(epochs_range, fcnn_res.get('val_loss'), label="FCNN")
plt.plot(epochs_range, cnn_res.get('val_loss'), label="CNN")
plt.legend()
plt.title("Pérdida de validación")
plt.show()

epochs_range = range(epochs)
plt.plot(epochs_range, fcnn_res.get('train_acc'), label="FCNN")
plt.plot(epochs_range, cnn_res.get('train_acc'), label="CNN")
plt.legend()
plt.title("Exactitud de entrenamiento")
plt.show()

epochs_range = range(epochs)
plt.plot(epochs_range, fcnn_res.get('val_acc'), label="FCNN")
plt.plot(epochs_range, cnn_res.get('val_acc'), label="CNN")
plt.legend()
plt.title("Exactitud de validación")
plt.show()

# %% [markdown]
# Ni en entrenamiento ni en validación FCNN alcanzó ni la mínima pérdida de CNN ni su gran exactitud. El rendimiento de CNN se estancó en ambas métricas prácticamente desde la época 2, aunque en validación era muy errática.

# %% [markdown]
# ### How many trainable parameters does each model have?
#
# Remember that each convolutional layer has $K \times (C_{in} \times k_h \times k_w + 1)$ parameters, where $K$ is the number of filters, $C_{in}$ is the number of input channels, $k_h$ and $k_w$ are the kernel height and width, and the +1 accounts for the bias term.
#
# Each fully connected layer has $N_{in} \times N_{out} + N_{out}$ parameters, where $N_{in}$ is the number of input features and $N_{out}$ is the number of output features.

# %% [markdown]
# FCNN
# Ya que la entrada tiene 28x28 características, es decir, la imagen tiene forma de 28x28 y que la primera capa tiene 512 características de salida, eso nos da que multiplicando 784 por 512 más 512 tenemos en la primera capa 4011920 parámetros. Para la segunda, haciendo el propio cálculo, ya que de la capa anterior salen 512 características y en esta salen 512 características, tenemos 512 por 512 más 512 es igual a 262656. Para la salida tenemos las 512 características de salida de la segunda capa y las 24 de salida de la salida. Entonces es 512 por 24 más 24, 12312. y ahora sumando 4011920 con 262656 y 12312, tenemos un total de 676,888 parámetros para la red FCNN.
#
# CNN
# Para la red convolucional se aplica la fórmula proporcionada y tenemos que para la primera capa los 25 filtros se multiplican con los canales de la imagen, que es 1, el tamaño del kernel, que es una matriz cuadrada de 3x3 y el bias term, lo que nos da un valor de 250 para la primera capa. Para la segunda capa tenemos 50 filtros multiplicados por los 25 filtros de la capa anterior, por el kernel 3x3 más el bias term, lo que nos da un valor de parámetros para la capa de 11,300. La siguiente capa, la número 3, tiene 75 filtros multiplicados por los 50 filtros de la capa anterior, por el kernel 3x3 más el bias term, dando un valor de 33,825. Para la cuarta capa tenemos que, ya que aplanamos los filtros anteriores de la capa 3, que eran 75, con el kernel 3x3 tenemos 75 por 3 por 3 multiplicado por las características de salida de esta capa, que son 512 más 512, lo que nos da un total para esta capa de 346,112 parámetros entrenados. Para la capa de salida y la última, tenemos que las 512 características de salida de la capa anterior se multiplican con las 24 características de salida de esta capa, más las mismas 24, lo que nos da un valor para esta capa de 12,312 y el total de todo esto sumado nos da un valor de parámetros entrenados para la red convolucional de 403,799 parámetros. Se hace la mención que tras el aplanado, la capa lineal y la capa de salida se comportan similar a una capa completamente conectada y por eso el cálculo se hace con la fórmula de la Fully Connected Layer, ya que únicamente estamos tratando con una matriz y ya no explotamos la vecinidad en este tramo de la CNN. Si me equivoco, corríjame.

# %% [markdown]
# ### How do the models compare in terms of overfitting? Why do you think that is the case?

# %% [markdown]
# Creo que CNN se aprendió el dataset y presenta algo de overfitting, ya que en entrenamiento alcanza casi el máximo estable pero en validación era más caótico. En prueba, de todas formas, resultó muy bueno.
#
# Para FCNN, no tengo palabras. Básicamente no aprendió ni los datos de entrenamiento ni los de validación; ya ni hablemos de la prueba. Tiene underfitting.

# %% [markdown]
# ### Final conclusions and remarks

# %% [markdown]
# No utilizaría FCNN, al menos no con esta arquitectura, para esta tarea. Me resulta asombroso que CNN fue prácticamente superior en todo.
